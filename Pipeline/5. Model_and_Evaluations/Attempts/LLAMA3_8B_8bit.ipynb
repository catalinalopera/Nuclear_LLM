# %% [markdown]
# # LLAMA3
# https://ai.meta.com/blog/meta-llama-3/
#
# https://github.com/meta-llama/llama3/blob/main/MODEL_CARD.md

# %% [markdown]
# # 1. Connecting to Google Drive and Changing Directory

# %%
import shutil, os, subprocess
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/MyDrive/Colab Notebooks/')
# Out:
# Mounted at /content/drive

# %%
! python --version
# Out:
# Python 3.10.12

# %% [markdown]
# # 2. GPU detection to prevent version conflicts

# %%
# %%capture
import torch
# !pip install bitsandbytes
# !pip install datasets
major_version, minor_version = torch.cuda.get_device_capability()
if major_version >= 8:
    # !pip install --no-deps packaging ninja einops flash-attn xformers trl peft accelerate bitsandbytes
else:
    # !pip install --no-deps xformers trl peft accelerate bitsandbytes
pass

# %%
# !pip list | grep transformers
# !pip list | grep torch
# !pip list | grep accelerate
# !pip list | grep bitsandbytes
# !pip list | grep peft
# !pip list | grep trl
# Out:
# transformers                     4.41.2
# torch                            2.3.0+cu121
# torchaudio                       2.3.0+cu121
# torchsummary                     1.5.1
# torchtext                        0.18.0
# torchvision                      0.18.0+cu121
# accelerate                       0.31.0
# bitsandbytes                     0.43.1
# peft                             0.11.1
# fastrlock                        0.8.2
# trl                              0.9.4

# %% [markdown]
# # 3. Import Python Packages

# %%
import torch, os, json, random, bitsandbytes as bnb, torch.nn as nn, psutil
from datasets import Dataset, DatasetDict, load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM, AutoModel, TrainingArguments
from peft import get_peft_model, LoraConfig # LoraConfig: Configuration for LoRA (Low-Rank Adaptation), a technique for parameter-efficient training.

# %% [markdown]
# # 4. Login to Hugging Face

# %%
from huggingface_hub import notebook_login
notebook_login() #TOKEN IS "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"
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# # 5. LLAMA 3 8B 8bit quantized

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
HF_TOKEN = "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"
model_name = "meta-llama/Meta-Llama-3-8B"
max_seq_length = 2048
tokenizer = AutoTokenizer.from_pretrained(model_name, token=HF_TOKEN)  # max_length=max_seq_length
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
special_tokens = tokenizer.special_tokens_map_extended
eos_token = tokenizer.eos_token
eos_token_id = tokenizer.eos_token_id

print("EOS Token:", eos_token)
print("EOS Token ID:", eos_token_id)
# Out:
# EOS Token: <|end_of_text|>
# EOS Token ID: 128001

# %%
special_tokens = tokenizer.special_tokens_map_extended
eos_token = tokenizer.eos_token
eos_token_id = tokenizer.eos_token_id

print("EOS Token:", eos_token)
print("EOS Token ID:", eos_token_id)
# Out:
# EOS Token: <|end_of_text|>
# EOS Token ID: 128001

# %%
quantization_config = BitsAndBytesConfig(load_in_8bit=True)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=quantization_config,
    device_map='auto',  # Otomatik olarak CPU ve GPU'ya dağıtma
    low_cpu_mem_usage=True,
    token=HF_TOKEN,

)     # max_length=max_seq_length,
# Out:
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/177 [00:00<?, ?B/s]

# %%
# Enter the sentence
text = "Hello, how are you?"
inputs = tokenizer(text, return_tensors="pt").to('cuda')

# Model testing
outputs = model.generate(**inputs)
generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(generated_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-9bd01e3f66c1> in <cell line: 6>()
#       4
#       5 # Model testing
# ----> 6 outputs = model.generate(**inputs)
#       7 generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
#       8
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1756
#    1757             # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 1758             result = self._sample(
#    1759                 input_ids,
#    1760                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2395
#    2396             # forward pass to get next token
# -> 2397             outputs = self(
#    2398                 **model_inputs,
#    2399                 return_dict=True,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     164                 output = module._old_forward(*args, **kwargs)
#     165         else:
# --> 166             output = module._old_forward(*args, **kwargs)
#     167         return module._hf_hook.post_forward(module, output)
#     168
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#    1162
#    1163         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1164         outputs = self.model(
#    1165             input_ids=input_ids,
#    1166             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     164                 output = module._old_forward(*args, **kwargs)
#     165         else:
# --> 166             output = module._old_forward(*args, **kwargs)
#     167         return module._hf_hook.post_forward(module, output)
#     168
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position)
#     966                 )
#     967             else:
# --> 968                 layer_outputs = decoder_layer(
#     969                     hidden_states,
#     970                     attention_mask=causal_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     164                 output = module._old_forward(*args, **kwargs)
#     165         else:
# --> 166             output = module._old_forward(*args, **kwargs)
#     167         return module._hf_hook.post_forward(module, output)
#     168
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position)
#     725         residual = hidden_states
#     726         hidden_states = self.post_attention_layernorm(hidden_states)
# --> 727         hidden_states = self.mlp(hidden_states)
#     728         hidden_states = residual + hidden_states
#     729
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     164                 output = module._old_forward(*args, **kwargs)
#     165         else:
# --> 166             output = module._old_forward(*args, **kwargs)
#     167         return module._hf_hook.post_forward(module, output)
#     168
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, x)
#     214             down_proj = sum(down_proj)
#     215         else:
# --> 216             down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#     217
#     218         return down_proj
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1530             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531         else:
# -> 1532             return self._call_impl(*args, **kwargs)
#    1533
#    1534     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1539                 or _global_backward_pre_hooks or _global_backward_hooks
#    1540                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541             return forward_call(*args, **kwargs)
#    1542
#    1543         try:
#
# /usr/local/lib/python3.10/dist-packages/accelerate/hooks.py in new_forward(module, *args, **kwargs)
#     164                 output = module._old_forward(*args, **kwargs)
#     165         else:
# --> 166             output = module._old_forward(*args, **kwargs)
#     167         return module._hf_hook.post_forward(module, output)
#     168
#
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/nn/modules.py in forward(self, x)
#     795             self.bias.data = self.bias.data.to(x.dtype)
#     796
# --> 797         out = bnb.matmul(x, self.weight, bias=self.bias, state=self.state)
#     798
#     799         if not self.state.has_fp16_weights:
#
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py in matmul(A, B, out, state, threshold, bias)
#     554     if threshold > 0.0:
#     555         state.threshold = threshold
# --> 556     return MatMul8bitLt.apply(A, B, out, bias, state)
#     557
#     558
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/function.py in apply(cls, *args, **kwargs)
#     596             # See NOTE: [functorch vjp and autograd interaction]
#     597             args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 598             return super().apply(*args, **kwargs)  # type: ignore[misc]
#     599
#     600         if not is_setup_ctx_defined:
#
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py in forward(ctx, A, B, out, bias, state)
#     319         if len(A.shape) == 3:
#     320             A = A.reshape(-1, A.shape[-1])
# --> 321         CA, CAt, SCA, SCAt, coo_tensorA = F.double_quant(A.to(torch.float16), threshold=state.threshold)
#     322
#     323         if state.threshold > 0.0 and coo_tensorA is not None:
#
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/functional.py in double_quant(A, col_stats, row_stats, out_col, out_row, threshold)
#    2517
#    2518     if row_stats is None or col_stats is None:
# -> 2519         row_stats, col_stats, nnz_row_ptr = get_colrow_absmax(A, threshold=threshold)
#    2520
#    2521     if out_col is None:
#
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/functional.py in get_colrow_absmax(A, row_stats, col_stats, nnz_block_ptr, threshold)
#    2400     tiled_rows = ((rows + 15) // 16) * 16
#    2401     if row_stats is None:
# -> 2402         row_stats = torch.empty((rows,), dtype=torch.float32, device=device).fill_(-50000.0)
#    2403     if col_stats is None:
#    2404         col_stats = torch.empty((cols,), dtype=torch.float32, device=device).fill_(-50000.0)
#
# KeyboardInterrupt:

# %%
# Checking model quantization
def is_8bit_quantized(model):
    for name, param in model.named_parameters():
        if param.dtype == torch.int8:
            print(f"Parameter {name} is quantized to 8-bit.")
        else:
            print(f"Parameter {name} is NOT quantized to 8-bit.")

is_8bit_quantized(model)
# Out:
# Parameter model.embed_tokens.weight is NOT quantized to 8-bit.
# Parameter model.layers.0.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.0.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.0.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.0.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.0.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.0.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.0.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.0.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.0.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.1.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.1.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.1.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.1.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.1.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.1.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.1.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.1.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.1.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.2.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.2.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.2.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.2.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.2.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.2.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.2.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.2.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.2.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.3.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.3.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.3.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.3.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.3.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.3.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.3.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.3.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.3.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.4.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.4.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.4.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.4.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.4.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.4.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.4.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.4.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.4.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.5.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.5.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.5.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.5.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.5.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.5.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.5.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.5.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.5.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.6.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.6.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.6.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.6.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.6.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.6.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.6.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.6.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.6.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.7.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.7.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.7.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.7.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.7.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.7.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.7.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.7.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.7.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.8.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.8.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.8.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.8.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.8.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.8.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.8.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.8.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.8.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.9.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.9.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.9.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.9.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.9.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.9.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.9.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.9.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.9.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.10.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.10.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.10.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.10.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.10.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.10.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.10.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.10.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.10.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.11.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.11.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.11.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.11.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.11.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.11.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.11.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.11.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.11.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.12.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.12.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.12.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.12.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.12.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.12.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.12.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.12.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.12.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.13.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.13.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.13.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.13.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.13.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.13.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.13.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.13.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.13.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.14.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.14.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.14.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.14.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.14.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.14.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.14.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.14.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.14.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.15.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.15.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.15.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.15.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.15.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.15.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.15.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.15.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.15.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.16.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.16.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.16.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.16.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.16.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.16.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.16.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.16.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.16.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.17.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.17.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.17.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.17.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.17.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.17.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.17.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.17.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.17.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.18.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.18.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.18.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.18.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.18.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.18.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.18.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.18.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.18.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.19.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.19.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.19.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.19.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.19.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.19.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.19.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.19.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.19.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.20.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.20.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.20.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.20.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.20.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.20.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.20.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.20.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.20.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.21.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.21.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.21.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.21.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.21.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.21.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.21.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.21.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.21.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.22.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.22.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.22.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.22.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.22.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.22.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.22.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.22.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.22.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.23.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.23.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.23.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.23.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.23.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.23.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.23.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.23.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.23.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.24.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.24.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.24.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.24.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.24.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.24.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.24.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.24.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.24.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.25.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.25.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.25.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.25.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.25.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.25.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.25.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.25.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.25.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.26.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.26.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.26.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.26.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.26.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.26.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.26.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.26.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.26.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.27.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.27.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.27.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.27.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.27.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.27.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.27.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.27.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.27.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.28.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.28.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.28.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.28.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.28.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.28.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.28.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.28.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.28.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.29.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.29.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.29.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.29.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.29.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.29.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.29.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.29.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.29.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.30.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.30.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.30.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.30.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.30.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.30.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.30.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.30.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.30.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.31.self_attn.q_proj.weight is quantized to 8-bit.
# Parameter model.layers.31.self_attn.k_proj.weight is quantized to 8-bit.
# Parameter model.layers.31.self_attn.v_proj.weight is quantized to 8-bit.
# Parameter model.layers.31.self_attn.o_proj.weight is quantized to 8-bit.
# Parameter model.layers.31.mlp.gate_proj.weight is quantized to 8-bit.
# Parameter model.layers.31.mlp.up_proj.weight is quantized to 8-bit.
# Parameter model.layers.31.mlp.down_proj.weight is quantized to 8-bit.
# Parameter model.layers.31.input_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.layers.31.post_attention_layernorm.weight is NOT quantized to 8-bit.
# Parameter model.norm.weight is NOT quantized to 8-bit.
# Parameter lm_head.weight is NOT quantized to 8-bit.

# %%
print(f"tokenizer memory usage: {psutil.virtual_memory().used / 1e9} GB")
print(f"Memory usage: {psutil.virtual_memory().used / 1e9} GB")
print("Memory usage summary after model setup:")
print(torch.cuda.memory_summary())
# Out:
# tokenizer memory usage: 2.749116416 GB
# Memory usage: 2.749116416 GB
# Memory usage summary after model setup:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |   9240 MiB |   9292 MiB |   1753 GiB |   1744 GiB |
# |       from large pool |   9216 MiB |   9279 MiB |   1623 GiB |   1614 GiB |
# |       from small pool |     23 MiB |    142 MiB |    130 GiB |    130 GiB |
# |---------------------------------------------------------------------------|
# | Active memory         |   9240 MiB |   9292 MiB |   1753 GiB |   1744 GiB |
# |       from large pool |   9216 MiB |   9279 MiB |   1623 GiB |   1614 GiB |
# |       from small pool |     23 MiB |    142 MiB |    130 GiB |    130 GiB |
# |---------------------------------------------------------------------------|
# | Requested memory      |   9235 MiB |   9286 MiB |   1735 GiB |   1726 GiB |
# |       from large pool |   9211 MiB |   9273 MiB |   1607 GiB |   1598 GiB |
# |       from small pool |     23 MiB |    142 MiB |    128 GiB |    128 GiB |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |   9530 MiB |   9530 MiB |  16300 MiB |   6770 MiB |
# |       from large pool |   9376 MiB |   9376 MiB |  16144 MiB |   6768 MiB |
# |       from small pool |    154 MiB |    154 MiB |    156 MiB |      2 MiB |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |  93790 KiB | 229896 KiB |   1522 GiB |   1522 GiB |
# |       from large pool |  85024 KiB | 224292 KiB |   1387 GiB |   1387 GiB |
# |       from small pool |   8766 KiB |  63097 KiB |    135 GiB |    135 GiB |
# |---------------------------------------------------------------------------|
# | Allocations           |    1150    |    1195    |   13760 K  |   13759 K  |
# |       from large pool |     349    |     357    |     254 K  |     253 K  |
# |       from small pool |     801    |     846    |   13506 K  |   13505 K  |
# |---------------------------------------------------------------------------|
# | Active allocs         |    1150    |    1195    |   13760 K  |   13759 K  |
# |       from large pool |     349    |     357    |     254 K  |     253 K  |
# |       from small pool |     801    |     846    |   13506 K  |   13505 K  |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |     290    |     290    |     400    |     110    |
# |       from large pool |     213    |     213    |     322    |     109    |
# |       from small pool |      77    |      77    |      78    |       1    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |     113    |     138    |   10021 K  |   10021 K  |
# |       from large pool |      26    |      45    |     109 K  |     109 K  |
# |       from small pool |      87    |     134    |    9911 K  |    9911 K  |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %%
total_params = sum(p.numel() for p in model.parameters())
print(f"total parameter: {total_params}")
# Out:
# total parameter: 8030261248

# %%
def model_size(model):
    total_size = 0
    for name, param in model.named_parameters():
        total_size += param.numel() * param.element_size()
    return total_size / (1024**2)  # MB

print(f"Dimension of Model: {model_size(model):.2f} MB")
# Out:
# Dimension of Model: 8660.51 MB

# %%
lora_config = {
    "r": 16,  # Number of LoRA layers
    "target_modules": ["q_proj", "k_proj", "v_proj", "o_proj",  # Target modules for LoRA
                       "gate_proj", "up_proj", "down_proj"],
    "lora_alpha": 16,  # Alpha value for LoRA (optional)
    "lora_dropout": 0.1,  # Dropout value for LoRA (optional)
    "bias": "none",  # Type of bias for LoRA (optional)
    "use_gradient_checkpointing": True,  # Use of gradient checkpointing
    "use_rslora": False,  # Use of RSLora (optional)
    "use_dora": False,  # Use of DoRa (optional)
    "loftq_config": None  # Configuration for LoFTQ (optional)
}

# %%
# Training configuration
training_config = {
    "per_device_train_batch_size": 2,        # Batch size per device
    "gradient_accumulation_steps": 4,        # Gradient accumulation steps
    "warmup_steps": 5,                       # Warmup steps
    "max_steps": 0,                          # Maximum steps (0 if epochs are defined)
    "num_train_epochs": 10,                  # Number of training epochs (0 if maximum steps are defined)
    "learning_rate": 2e-4,                   # Learning rate
    "fp16": not torch.cuda.is_bf16_supported(),  # Use fp16 if bf16 is not supported
    "bf16": torch.cuda.is_bf16_supported(),  # Use bf16 if supported
    "logging_steps": 1,                      # Logging steps
    "optim": "adamw",                        # Optimizer
    "weight_decay": 0.01,                    # Weight decay
    "lr_scheduler_type": "linear",           # Learning rate scheduler
    "seed": 42,                              # Seed value
    "output_dir": "outputs",                 # Output directory
}

# %%
# QLORA
# class QLoRAModel(nn.Module):
#     def __init__(self, base_model_name, r, target_modules, lora_alpha=None, lora_dropout=None, bias=None,
#                  use_gradient_checkpointing=True, use_rslora=False, use_dora=False, loftq_config=None):
#         super(QLoRAModel, self).__init__()

#         # Load base model and tokenizer
#         self.base_model = AutoModelForCausalLM.from_pretrained(base_model_name)
#         self.tokenizer = AutoTokenizer.from_pretrained(base_model_name)

#         self.r = r
#         self.target_modules = target_modules
#         self.lora_alpha = lora_alpha
#         self.lora_dropout = lora_dropout
#         self.bias = bias
#         self.use_gradient_checkpointing = use_gradient_checkpointing
#         self.use_rslora = use_rslora
#         self.use_dora = use_dora
#         self.loftq_config = loftq_config

#         # Setup LoRA layers
#         self.setup_lora()

#     def setup_lora(self):
#         for name, module in self.base_model.named_modules():
#             if any(target_module in name for target_module in self.target_modules):
#                 if isinstance(module, nn.Linear):
#                     # Replace linear layers with LoRA-adapted linear layers
#                     out_features = module.out_features
#                     in_features = module.in_features
#                     setattr(self.base_model, name, LoRALinear(in_features, out_features, self.r,
#                                                              alpha=self.lora_alpha, dropout=self.lora_dropout,
#                                                              bias=self.bias))

#     def forward(self, input_ids, attention_mask=None):
#         outputs = self.base_model(input_ids=input_ids, attention_mask=attention_mask)
#         return outputs

# class LoRALinear(nn.Module):
#     def __init__(self, in_features, out_features, r, alpha=None, dropout=None, bias=None):
#         super(LoRALinear, self).__init__()
#         self.in_features = in_features
#         self.out_features = out_features
#         self.r = r
#         self.alpha = alpha
#         self.dropout = dropout
#         self.bias = bias

#         # Define LoRA-adapted linear layers here
#         self.fc1 = nn.Linear(in_features, r)
#         self.fc2 = nn.Linear(r, out_features)

#     def forward(self, x):
#         x = self.fc1(x)
#         # Apply activation function if necessary
#         x = nn.functional.relu(x)

#         # Apply dropout if specified
#         if self.dropout:
#             x = nn.functional.dropout(x, p=self.dropout, training=self.training)

#         x = self.fc2(x)

#         # Apply bias if specified
#         if self.bias:
#             x = x + self.bias

#         return x
