# %% [markdown]
# #### This notebook demonstrates the initialization and usage of the LLAMA3 language model with 8-bit quantization using Hugging Face's Transformers library for generating QA pairs from pdf dcuments.
#
# Key steps include:
# 1. Installing and importing necessary libraries (`transformers` for model handling and `bitsandbytes` for quantization).
# 2. Initializing the tokenizer and model with 8-bit quantization to optimize memory usage while maintaining performance.
# 3. Automatically distributing the model across available devices (e.g., GPUs) to leverage computational resources effectively.
# 4. Managing model checkpoints and loading them efficiently to handle large model files.
#
# This setup is particularly useful for running large language models on limited hardware resources.

# %%
# !pip install bitsandbytes datasets transformers peft accelerate tqdm pandas PyMuPDF
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.43.3-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Collecting datasets
#   Downloading datasets-2.20.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Collecting peft
#   Downloading peft-0.12.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.32.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Collecting PyMuPDF
#   Downloading PyMuPDF-1.24.9-cp310-none-manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.3.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.15.4)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting requests>=2.32.2 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.5.0,>=2023.1.0 (from fsspec[http]<=2024.5.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.5.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.0)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Collecting PyMuPDFb==1.24.9 (from PyMuPDF)
#   Downloading PyMuPDFb-1.24.9-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.3.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->bitsandbytes)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->bitsandbytes)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->bitsandbytes)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->bitsandbytes)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->bitsandbytes)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->bitsandbytes)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->bitsandbytes)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->bitsandbytes)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->bitsandbytes)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->bitsandbytes)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->bitsandbytes)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes) (1.3.0)
# Downloading bitsandbytes-0.43.3-py3-none-manylinux_2_24_x86_64.whl (137.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 MB 4.9 MB/s eta 0:00:00
# Downloading datasets-2.20.0-py3-none-any.whl (547 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 547.8/547.8 kB 12.1 MB/s eta 0:00:00
# Downloading peft-0.12.0-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.4/296.4 kB 15.4 MB/s eta 0:00:00
# Downloading PyMuPDF-1.24.9-cp310-none-manylinux2014_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 31.4 MB/s eta 0:00:00
# Downloading PyMuPDFb-1.24.9-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (15.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 55.2 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.2 MB/s eta 0:00:00
# Downloading fsspec-2024.5.0-py3-none-any.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.1/316.1 kB 16.2 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 13.2 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 3.5 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 403.8 kB/s eta 0:00:00
# Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.1 MB/s eta 0:00:00
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Installing collected packages: xxhash, requests, PyMuPDFb, pyarrow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fsspec, dill, PyMuPDF, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, nvidia-cusolver-cu12, datasets, bitsandbytes, peft
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.6.1
#     Uninstalling fsspec-2024.6.1:
#       Successfully uninstalled fsspec-2024.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# gcsfs 2024.6.1 requires fsspec==2024.6.1, but you have fsspec 2024.5.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed PyMuPDF-1.24.9 PyMuPDFb-1.24.9 bitsandbytes-0.43.3 datasets-2.20.0 dill-0.3.8 fsspec-2024.5.0 multiprocess-0.70.16 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 peft-0.12.0 pyarrow-17.0.0 requests-2.32.3 xxhash-3.4.1

# %%
import os
import glob
import re
import pandas as pd
from tqdm import tqdm
import fitz  # PyMuPDF
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import LoraConfig

# %%
# Load configuration
SOURCE_DIRECTORY = '/content/drive/MyDrive/Colab Notebooks/WIP_kitectrics/CNSC'
chunk_size = 2000
chunk_overlap = 0
HF_TOKEN = "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"
model_name = "meta-llama/Meta-Llama-3-8B"

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Initialize the LLAMA3 model with 8-bit quantization from Hugging Face
tokenizer = AutoTokenizer.from_pretrained(model_name, use_auth_token=HF_TOKEN)
quantization_config = BitsAndBytesConfig(load_in_8bit=True)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=quantization_config,
    device_map='auto',  # Automatically distribute model to available devices
    low_cpu_mem_usage=True,
    use_auth_token=HF_TOKEN
    )
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py:778: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py:469: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/177 [00:00<?, ?B/s]

# %%
# Function to read and clean all PDFs
def extract_text_from_pdfs(directory):
    text_data = []
    for pdf_file in glob.glob(os.path.join(directory, "*.pdf")):
        print(f"Reading PDF: {pdf_file}")
        doc = fitz.open(pdf_file)
        text = ""
        for page in doc:
            text += page.get_text()
        text_data.append(text)
    return text_data

# %%
# Convert documents to chunks
def chunk_text(text, chunk_size=2000, chunk_overlap=0):
    start = 0
    chunks = []
    while start < len(text):
        end = start + chunk_size
        chunks.append(text[start:end])
        start += chunk_size - chunk_overlap
    return chunks

# %%
# Prompt to use LLAMA3 API as QA generator
qa_prompt_template = """
You are an AI assistant tasked with generating question-answer pairs for fine-tuning a large language model (LLM).
Each question should be formatted as <question>Your question here</question> and each answer as <answer>Your answer here</answer>.
Use only the information provided in the context to create relevant and contextually accurate questions and answers.

Context: {context}

Q&A:

<question>What is the purpose of Dosimetry in radiation protection?</question>
<answer>The purpose of Dosimetry in radiation protection is to accurately measure and assess the radiation doses received by individuals working in environments where they may be exposed to radiation.</answer>
"""

# %%
# Generate QA pairs for the first 3 chunks
def generate_qa_pairs(chunks):
    qa_pairs = []
    for chunk in tqdm(chunks[:3], desc="Generating QA pairs for first 3 chunks"):
        try:
            prompt = qa_prompt_template.format(context=chunk)
            inputs = tokenizer(prompt, return_tensors="pt").to('cuda')
            outputs = model.generate(
                **inputs,
                max_length=2048,
                num_return_sequences=1,
                do_sample=True,
                temperature=1.8,
                top_p=0.90,
                top_k=50
            )
            generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

            # Extract Q&A pairs from the generated text
            qa_start = generated_text.find("Q&A:")
            if qa_start != -1:
                qa_text = generated_text[qa_start + len("Q&A:"):]
                qa_pairs.extend(qa_text.strip().split('\n'))
            else:
                print("No Q&A found in the generated text.")
        except Exception as e:
            print(f"Error generating QA for chunk: {e}")
    return qa_pairs

# %%
# Main execution
if __name__ == "__main__":
    text_data = extract_text_from_pdfs(SOURCE_DIRECTORY)
    print(f"Extracted text from {len(text_data)} PDFs")  # Debugging statement
    all_qa_pairs = []

    for text in text_data:
        chunks = chunk_text(text, chunk_size=chunk_size, chunk_overlap=chunk_overlap)
        qa_pairs = generate_qa_pairs(chunks)
        all_qa_pairs.extend(qa_pairs)

    # Post-processing: Ensure each question has an answer
    complete_qa_pairs = []
    for qa in all_qa_pairs:
        if "<question>" in qa and "<answer>" in qa:
            complete_qa_pairs.append(qa)
        else:
            print(f"Incomplete QA pair found: {qa}")  # Debugging statement

    # Print the first 20 questions for debugging
    print("Generated QA pairs for the first 3 chunks:")
    for i, qa in enumerate(complete_qa_pairs[:20]):
        print(f"{i+1}. {qa}")
# Out:
# Reading PDF: /content/drive/MyDrive/Colab Notebooks/WIP_kitectrics/CNSC/REGDOC-1_4_1__Class_II_Nuclear_Facilities_and_Prescribed_Equipment.pdf
# Reading PDF: /content/drive/MyDrive/Colab Notebooks/WIP_kitectrics/CNSC/REGDOC-1-1-1-site-evaluation-site-preparation-for-new-reactor-facilities-v1-2.pdf
# Extracted text from 2 PDFs
# Generating QA pairs for first 3 chunks:   0%|          | 0/3 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating QA pairs for first 3 chunks:  33%|███▎      | 1/3 [05:27<10:55, 327.69s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating QA pairs for first 3 chunks:  67%|██████▋   | 2/3 [06:44<03:00, 180.05s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating QA pairs for first 3 chunks: 100%|██████████| 3/3 [07:14<00:00, 144.79s/it]
# Generating QA pairs for first 3 chunks:   0%|          | 0/3 [00:00<?, ?it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating QA pairs for first 3 chunks:  33%|███▎      | 1/3 [00:00<00:01,  1.84it/s]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating QA pairs for first 3 chunks:  67%|██████▋   | 2/3 [06:05<03:34, 214.72s/it]Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generating QA pairs for first 3 chunks: 100%|██████████| 3/3 [07:36<00:00, 152.18s/it]
# Incomplete QA pair found: <question>What is the purpose of Dosimetry in radiation protection?</question>
# Incomplete QA pair found: <answer>The purpose of Dosimetry in radiation protection is to accurately measure and assess the radiation doses received by individuals working in environments where they may be exposed to radiation.</answer>
# Incomplete QA pair found:
# Incomplete QA pair found: # Answer should mention:
# Incomplete QA pair found: Measure of total cumulative effects of the action or radiation or radioactivity.
# Incomplete QA pair found: Can be total effective body (whole-body) dose equivalent or equivalent organ.
# Incomplete QA pair found: Individuals who must provide and wear dosimeter badge for work within areas where dose may
# Incomplete QA pair found: exceed the controlled exposure limits must comply.
# Incomplete QA pair found: Determine worker dose limits or control values; used in occupational radiation protection; or control program.
# Incomplete QA pair found: Determines the worker’s actual level of risk based on radiation dosage exposure and length of exposure
# Incomplete QA pair found: Time between successive doses of different parts.
# Incomplete QA pair found: Measure all the energy the beam transfers to material being measured in a very specific amount of time
# Incomplete QA pair found:
# Incomplete QA pair found: <question>Is dosimetry a unit of quantity? Name two</question>
# Incomplete QA pair found: <answer>Dosimetry is measured in either effective units which are measured dose, exposure values and air Kerma or specific activities; Effective or dose effective (sieverts & grey), Roentgen (c/g), air Kerma and specific activity.</answer>
# Incomplete QA pair found: # Answer should mention: Doses in Sieverts & dose equivalent in rads and microsieverts and exposure rate
# Incomplete QA pair found:
# Incomplete QA pair found: <question>Is Dosimetry unit used for radiation damage of organs?</question>
# Incomplete QA pair found: <answer>Yes, organ damage are measure under three headings of total body dose, effective wholebody dose
# Incomplete QA pair found: (Dose)
# Incomplete QA pair found: Doses in Sieverts effective radiation or dose (Sv)
# Incomplete QA pair found: doses or irradiance of the organs and exposure or equivalent.
# Incomplete QA pair found: Total organ dose limit, (0.05 Sv annual)
# Incomplete QA pair found: Cumulative limit for dose, (0.30 Sv)
# Incomplete QA pair found: Doses or roentgens effective dose limits</answer>
# Incomplete QA pair found:
# Incomplete QA pair found: ## Commented Ans (1-6,8,9)
# Incomplete QA pair found: ### Example1.
# Incomplete QA pair found: Class of nuclear Facilities - Is an industrial radioactive installations for nuclear power generation purposes.
# Incomplete QA pair found:
# Incomplete QA pair found: This example of application should help students know the types of facilities, purpose, activities and
# Incomplete QA pair found: related risk factors with dosages used:
# Incomplete QA pair found:
# Incomplete QA pair found: In many of Class 1 type applications of this document in different type of facilities.
# Incomplete QA pair found: 1) Nuclear power facilities that involve high and complex operations as part a nuclear power station or the
# Incomplete QA pair found: site should have:
# Incomplete QA pair found: (For Class 1 installations):
# Incomplete QA pair found: 1)1. Application of highly hazardous substances, for instance large production volume with dangerous and
# Incomplete QA pair found: dangerous activities;
# Incomplete QA pair found: 1)1.4.  Complex technologies, complex engineering;
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found: i.e) It can include fuel and spent fuel cycles, chemical plants processing
# Incomplete QA pair found: large quantities of such material; Nuclear fusion, particle physics applications
# Incomplete QA pair found: with radioisotopes, radioactive or potentially radioactive hazardous activities
# Incomplete QA pair found:
# Incomplete QA pair found: 1)3) Operation on a continuous basis
# Incomplete QA pair found: 1)4.  Major installations in densely populated areas with special features (water supply areas);
# Incomplete QA pair found: For such applications are likely a higher incidence and higher concentrations
# Incomplete QA pair found: in working conditions with a more active radioactive substance, which could lead
# Incomplete QA pair found: to a relatively large exposures;
# Incomplete QA pair found: Also, due attention
# Incomplete QA pair found: shall paid in terms the total dose effective body due cumulative
# Incomplete QA pair found: impact.
# Incomplete QA pair found: Application of highly hazardous material should monitored continuously or automatically, if necessary
# Incomplete QA pair found: to provide emergency action.
# Incomplete QA pair found:
# Incomplete QA pair found: *Examples of dosimetry:
# Incomplete QA pair found: Total effective (body)
# Incomplete QA pair found: Total
# Incomplete QA pair found: radiant body energy
# Incomplete QA pair found: Energetic transfer and total radiation energy absorbed into human bodies at any instant
# Incomplete QA pair found:
# Incomplete QA pair found: Dose, irradiation, etc:
# Incomplete QA pair found: Exposure, (roentgen c, per g.)
# Incomplete QA pair found: Air Kerma,
# Incomplete QA pair found: dose effective body or organ (S or sv)
# Incomplete QA pair found: dose effect on organ ( Sv )
# Incomplete QA pair found:
# Incomplete QA pair found: Effective organs:
# Incomplete QA pair found: Roentgens and grays;
# Incomplete QA pair found:
# Incomplete QA pair found: Radiant energy transfer is a transfer rate by means. Total and radiant energies are
# Incomplete QA pair found: Total and radiant energies are two forms (effective forms of energy):
# Incomplete QA pair found: Radiation energy of a radioactive substance are not all
# Incomplete QA pair found: in a radioactive substance are radiation and decay energies not all released into environment;
# Incomplete QA pair found:
# Incomplete QA pair found: Total of radiation released radiation transferred into living things as in air Kerma or energy transfers into body tissue.
# Incomplete QA pair found: Effective dose as total of the whole-body doses in terms cumulative effect
# Incomplete QA pair found:
# Incomplete QA pair found: All total effects on human body shall have an immediate effective or
# Incomplete QA pair found: whole body dose effective (in sv. Effective total
# Incomplete QA pair found: body effects) and also as exposure and radiation equivalent energy transferred (E). All dose quantities are
# Incomplete QA pair found: effective forms that allow to have proper control and limits. All radiolabed doses, energy and radiation exposure
# Incomplete QA pair found: should taken as an effective value so no any human effects.
# Incomplete QA pair found:
# Incomplete QA pair found: Radiant energy (energy release with a medium like heat and light).
# Incomplete QA pair found: Radiant dose
# Incomplete QA pair found: Efficacy of dose
# Incomplete QA pair found: Effective energy
# Incomplete QA pair found: effective or cumulative exposure or effective exposures
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found: Examples
# Incomplete QA pair found: Class 0 – Research only, low-risk
# Incomplete QA pair found: In this example:
# Incomplete QA pair found: Activity of such Class 0 facilities not high with lower level and intensity of a radioactive
# Incomplete QA pair found: substance and with a limited level with activities of such type of a research facility.
# Incomplete QA pair found: All staff and public, exposure shall limited, including staff
# Incomplete QA pair found: with occupational risks,
# Incomplete QA pair found: the facility with controlled and restricted areas to
# Incomplete QA pair found: protect people of the public exposure shall be taken measures
# Incomplete QA pair found: for any facility operating.
# Incomplete QA pair found: It shall consider for the total
# Incomplete QA pair found: level with radiations,
# Incomplete QA pair found: the impact.
# Incomplete QA pair found:
# Incomplete QA pair found: Total radiation in environment and dose levels should control
# Incomplete QA pair found: for such application to ensure exposure limits with respect to radiations
# Incomplete QA pair found: Exclusion areas
# Incomplete QA pair found: are not mandatory for all small facilities and any radiation control
# Incomplete QA pair found: with respect exposure risk.
# Incomplete QA pair found:
# Incomplete QA pair found: *Answer Example
# Incomplete QA pair found: (Answer the question in a sentence using an accepted definition for key terms) (6+2):
# Incomplete QA pair found: In Class 4 type of installation there are various applications with
# Incomplete QA pair found: complex materials
# Incomplete QA pair found: including radioisotope research labs including complex applications,
# Incomplete QA pair found: Particle accelerations and with research
# Incomplete QA pair found: purposes that need a larger dose (up to several röntegen and gray level per microsievelt as with
# Incomplete QA pair found: particle accelerations) for high-energy and dose effects applications.
# Incomplete QA pair found: All radiation effects (E) to an environment should considered
# Incomplete QA pair found: effect (E).
# Incomplete QA pair found: Effects should be reduced to a
# Incomplete QA pair found: acceptable minimum radiation doses to
# Incomplete QA pair found: reduce adverse effects with total radiation effects at a whole body (WB dose or dose total) or body and any radiation effects to other living creatures (other creatures and their
# Incomplete QA pair found: surroondig living cells).
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found: In some facilities like nuclear particle acceleration and research and related technologies applications
# Incomplete QA pair found: have been involved complex processes and applications using high radiation energy. Radiation with higher energies
# Incomplete QA pair found: requires high protective measures and controlled work environments.
# Incomplete QA pair found: Dose levels or energy limits need an higher attention for these facilities, as a minimum doses levels and energy
# Incomplete QA pair found: radiation control limits and exposures limits with radiations.
# Incomplete QA pair found:
# Incomplete QA pair found: To limit a risk in a nuclear facilities or application environment with radiations at whole body (WBP), other parts and
# Incomplete QA pair found: their living tissues (cells, body cells,
# Incomplete QA pair found: etc)
# Incomplete QA pair found: shall consider total dose effective as doses levels limits or values. Also with other risk factors (E = Exposure)
# Incomplete QA pair found:
# Incomplete QA pair found: and total energy (A total energy absorbed)
# Incomplete QA pair found: exposure to a maximum.
# Incomplete QA pair found:
# Incomplete QA pair found: Effective whole body limits need consider with different levels of
# Incomplete QA pair found: radiated energy values as
# Incomplete QA pair found: <question>What is the purpose of Dosimetry in radiation protection?</question>
# Incomplete QA pair found: <answer>The purpose of Dosimetry in radiation protection is to accurately measure and assess the radiation doses received by individuals working in environments where they may be exposed to radiation.</answer>
# Incomplete QA pair found:
# Incomplete QA pair found:     <question> What information must be on Class2 Dosimetry badges </quesition>
# Incomplete QA pair found:
# Incomplete QA pair found:      <answer>
# Incomplete QA pair found:       1 The number of the facility or prescribed activity licence: <br></br> (2) A description
# Incomplete QA pair found:       	1 Name, number and organization unit of license holder <br>< br>
# Incomplete QA pair found:       	- Date of issue/receipt/denotun <br></br> </p></td>>
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found: </answer>
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found: <question></question>
# Incomplete QA pair found: <question>Why and by what means, and how to measure in dose the exposure received
# Incomplete QA pair found:           in time <i>t i</i>, a single organ / critical tissue / whole organism and on all organs?  </question>
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found: </question>
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found: Question - When do people need individual monitoring?
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found: What is the definition given by the International Committee on Safety of Radioactive Contamination?
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found: Why individual measurements (measurement of internal irradiation, personal dosimeters), who should take part in this individual dosimetry in a particular laboratory?
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found: Question:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found: <question>Tell something for your own application for using any type on nuclear materials or machines
# Incomplete QA pair found:  </question>
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found: <answer>Satisfies or Not the requirement of your specific question
# Incomplete QA pair found:  </answer>
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:       <a> The purpose </a><br>
# Incomplete QA pair found:    <ol><li> Provide safe & efficte <br/>
# Incomplete QA pair found: <li>Increase productivity to increase the safety performance</li>
# Incomplete QA pair found: 	 <li>Mitgategting and management of incidents (accidents)
# Incomplete QA pair found:
# Incomplete QA pair found: </ol>
# Incomplete QA pair found: <question>What is the purpose of Dosimetry in radiation protection?</question>
# Incomplete QA pair found: <answer>The purpose of Dosimetry in radiation protection is to accurately measure and assess the radiation doses received by individuals working in environments where they may be exposed to radiation.</answer>
# Incomplete QA pair found:
# Incomplete QA pair found: <question>What should healthcare providers ensure they always include in a Patient consent to receive COVID-19 related health information for contact tracing purposes Form?
# Incomplete QA pair found: </question>
# Incomplete QA pair found:     <answer>All necessary and essential information to contact an emergency department
# Incomplete QA pair found:     Infection control officer
# Incomplete QA pair found:     Occupational health team
# Incomplete QA pair found:     Outpatient clinics and walk in centres
# Incomplete QA pair found:     Physiotherapy
# Incomplete QA pair found: </answer>
# Incomplete QA pair found: <https://www.canada.ca/en/services/agriculture-fisheriesforestry/science.html>
# Incomplete QA pair found: <question>If a student is going abroad, which visa type will enable them to live, work and study without conditions in Australia?</question>
# Incomplete QA pair found: <question>What is the purpose of Dosimetry in radiation protection?</question>
# Incomplete QA pair found: <answer>The purpose of Dosimetry in radiation protection is to accurately measure and assess the radiation doses received by individuals working in environments where they may be exposed to radiation.</answer>
# Incomplete QA pair found: <question>What is the purpose of Dosimetry in radiation protection?</question>
# Incomplete QA pair found: <answer>The purpose of Dosimetry in radiation protection is to accurately measure and assess the radiation doses received by individuals working in environments where they may be exposed to radiation.</answer>
# Incomplete QA pair found: What safety requirements are specified during design phases?
# Incomplete QA pair found: The design review document specifies that CNSC acceptance should be obtained during key
# Incomplete QA pair found: design phases of both new and existing facility projects, including (i) general layout; (ii) safety case and licence
# Incomplete QA pair found: case; (iii) preliminary system safety basis and supporting design information; (iv) key system components and main
# Incomplete QA pair found: structure system basis document; (v) main primary circuit module and containment system design; (vi) major
# Incomplete QA pair found: technical equipment safety design documentation (including major and minor safety class system equipment, all as
# Incomplete QA pair found: determined per AL-5.05); and (vi) design assessment and conclusion of all the major safety systems and the supporting
# Incomplete QA pair found: structures.
# Incomplete QA pair found: The design information should be adequate in that it allows CNSC staff and other reviewing bodies with suitable
# Incomplete QA pair found: experience (where applicable) to complete the review and to satisfy and meet design control measures at least
# Incomplete QA pair found: per the requirements as stipulated within the project licensing documentation.
# Incomplete QA pair found:
# Incomplete QA pair found: For a new facility application submission in a multi-national entity's jurisdiction, the Commission may conduct on-site inspections with representatives of any foreign governmental authority having responsibility in relation to matters relevant to safety. Do you have the correct type of inspection request letter prepared?
# Incomplete QA pair found: No the IAEA (not yet)
# Incomplete QA pair found: Should be a request by a government official to a reactor facility
# Incomplete QA pair found: No, wrong language
# Incomplete QA pair found: Wrong letter format
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found: What level of protection or assurance levels apply to site safety studies on a facility, with the potential of having multiple extreme external event (EME) and internal event conditions present that will affect different systems?
# Incomplete QA pair found: The most important level of protection to site safety studies regarding multiple extreme external or simultaneous external/internal combinations on a facility involves
# Incomplete QA pair found: the robust characterization of a proposed new nuclear fuel fabrication facility design
# Incomplete QA pair found: a multi-normative and risk-informed analysis in accordance with guidance given out
# Incomplete QA pair found: The level of protection for safety studies based primarily upon a probabilistic event-specific methodology involving an extensive screening (compliant with requirements from CNSC) approach where:
# Incomplete QA pair found: •
# Incomplete QA pair found: robust characterization, using multi-parameter and quantitative risk methods; and
# Incomplete QA pair found: •
# Incomplete QA pair found: comparable results achieved from conservative and safety analyses approaches
# Incomplete QA pair found: How is an emergency zone (which should be separate for non-local external events not addressed below for illustration purposes and local site external events) separated from all reactor facility areas when preparing its sites? Please explain briefly, without providing any further documentation unless required as a result of providing more information
# Incomplete QA pair found: All reactor plant buildings at the planned GNF&F site boundaries will
# Incomplete QA pair found: remain within a dedicated restricted area of 150 ha for the first year of operation of the planned facility in order
# Incomplete QA pair found: the separation of its building structures away from any areas of public occupancy.
# Incomplete QA pair found: Separation criteria (e.g. radiation shielded walls,
# Incomplete QA pair found: ventilated spaces, barriers with doors, safety guards that need not operate in case of severe internal events at 10-20 kPa; air filters required to ensure an area free of airborne radioactive contamination)
# Incomplete QA pair found: This distance was also chosen based upon a number (7m wide corridor, separated in different areas from normal facility construction workers) set by both Canadian Federal Law (Health Law)
# Incomplete QA pair found: The GNNFP site building structure(s) layout will feature reinforced foundations where concrete pads should include
# Incomplete QA pair found: safety-reinforcement against earthquake effects. These concrete slab pads are reinforced internally (in their own structure), not part of the overall concrete wall thickness.
# Incomplete QA pair found: Any design considerations must be approved in relation to an emergency planning criteria zone distance and design considerations in terms of ensuring the proper design basis events.
# Incomplete QA pair found:
# Incomplete QA pair found: What is considered as a “key system” in designing a primary and secondar (P&SUHS)?
# Incomplete QA pair found:     The P&SUH is defined as a "key" structure which includes many of the nuclear systems such as main primary components (the reactors core) and emergency pumps etc.) and contains a single common containment
# Incomplete QA pair found:     The main components (like the main piping system) that need attention are grouped inside single (PandS) zones as a whole, but their location inside the main (PandS) structures is designed (including many supporting (or) support structure components for) to separate from other less vital (such as auxiliary equipment in areas located outside of these structures and main structural elements to increase overall earthquake/seismic protection levels).
# Incomplete QA pair found: The P&SU systems are also divided between major structural equipment, support building parts (e.g.gates), all other areas in the (NPP), emergency (systems related building parts) parts etc. etc., to provide maximum (for protection in case of accidental shutdown or events related to safety measures for example in case of) isolation and safety redundancy if needed for future maintenance, operations etc. etc..
# Incomplete QA pair found:     A P+SUPUZ and related PUPUZ are connected/ integrated into a major component (for both electrical and non-electrical systems within the facility complex) as well as a single "overall P-S system, " and the overall building support structure design consists of both single component systems. The single containment and all the other building structural walls (along with their reinforced concrete foundations as described next page 8/36
# Incomplete QA pair found:     This is defined specifically here so I added a definition of "key elements, " see below.
# Incomplete QA pair found: P+SUPS: The main component (like reactors coolant systems)
# Incomplete QA pair found: Nuclear Systems in a Reactor Facility
# Incomplete QA pair found: - Primary systems (including reactor coolant and/or coolant tanks, primary circulation
# Incomplete QA pair found: equipment, valves on both inlet (feed) and inlet streams or other auxiliary system)
# Incomplete QA pair found: – The coolant (as the main reactor) is circulating inside both sides of the reactor cooling channel
# Incomplete QA pair found: in terms with both reactor safety parameters including a "heat rejection control valve and associated
# Incomplete QA pair found: auxiliary circuits."
# Incomplete QA pair found: In case of both a small coolant loop cooling failure and some (minor, as a possible accident scenario which could lead to catastrophic (e, or damage) consequences depending on system location) potential problems
# Incomplete QA pair found: therefore require a redundant reactor primary cooling system such as a "backup emergency reactor core safety
# Incomplete QA pair found: device
# Incomplete QA pair found: Secondary Systems: These are located after (and often as a separate unit from a Primary System Unit). Both have separate connections, different feed and return flow lines within a same reactor coolant loop;
# Incomplete QA pair found: the main heat exchangers for removing heat (water). A second coolant loop with a different circuit path would be useful to support one and only one reactor system only while reducing maintenance risks compared against a system with an identical layout but operating through separate components (which is more complicated)
# Incomplete QA pair found:
# Incomplete QA pair found: Main Auxiliary Circuits and Support Structures:
# Incomplete QA pair found:
# Incomplete QA pair found: This includes the auxiliary circuit structure with separate inlet connections from the feedwater
# Incomplete QA pair found: line and the reactor cold source feed. An electrical feed that allows these systems
# Incomplete QA pair found: to start in less that a 30-second operational condition upon a loss of normal AC power would be one
# Incomplete QA pair found: typical approach when operating both reactors with one large loop circulating water supply or
# Incomplete QA pair found: inlet/outlet points between each circuit.
# Incomplete QA pair found:
# Incomplete QA pair found: Main Building Supports (S, SBSSA):
# Incomplete QA pair found:
# Incomplete QA pair found: All auxiliary and other electrical/ventilating/electromagnet etc., as a "single integrated (synchronized by all) main (support) building supporting (main structural, equipment for example and a power circuit to start systems such) support equipment building area support structure, " a separate building support building complex" (as noted below). This separate support building supports several of both smaller reactor cooling units inside single loop reactor and one overall safety equipment complex. This means "an integrated support of entire facility (including any smaller or secondary support) including cooling units" should always occur first so any possible "potential failures within each reactor cooling loop can lead (if not already detected during design stages through redundant design measures) to overall reactor facility shut- don/serious damages if not corrected (as soon) once detected during operations" (note).
# Incomplete QA pair found: <question>What is the purpose of Dosimetry in radiation protection?</question>
# Incomplete QA pair found: <answer>The purpose of Dosimetry in radiation protection is to accurately measure and assess the radiation doses received by individuals working in environments where they may be exposed to radiation.</answer>
# Incomplete QA pair found:
# Incomplete QA pair found: <question> What information is important for dosimetry and radiation protection?</question>
# Incomplete QA pair found: <answer>The following information is important for dosimetry and radiation protection:
# Incomplete QA pair found:     1. Radiation source, form and quantity
# Incomplete QA pair found:     2. Working time period
# Incomplete QA pair found: 3.Personnel distribution of personnel
# Incomplete QA pair found: 4.Procedures required by radiation protection
# Incomplete QA pair found: 5.Maintain records and data</answer>
# Incomplete QA pair found:
# Incomplete QA pair found:
# Incomplete QA pair found: Q&A: What are the responsibilities of Radiation Protection?
# Incomplete QA pair found: </br>
# Incomplete QA pair found: <question>What are the responsibilities of Radiation Protection and what are they expected from these roles?</question>
# Incomplete QA pair found: <answer>These are the general expectations from these roles:
# Incomplete QA pair found:
# Incomplete QA pair found: (2) The responsibility of Radiation Protection is to plan to eliminate radiation risks where reasonable practicable
# Incomplete QA pair found: to do so. If eliminating these risks is technically not achievable, then
# Incomplete QA pair found: it's reasonable practice and responsibility to implement the highest practical degree of radiation control
# Incomplete QA pair found: This means radiation must remain well underneath safety requirements where it may lead to health
# Incomplete QA pair found: and environmental consequences.
# Incomplete QA pair found: In summary Radiation must ensure that radiation exposures are not too high with potential harm.
# Incomplete QA pair found:
# Incomplete QA pair found: It's of utmost important Radiation has full information or reasonable to achieve reasonable best possible
# Incomplete QA pair found: assessment on radiation that's in any environment around
# Incomplete QA pair found: So as to maintain any protection from harmful health & environmental impacts </answer>
# Incomplete QA pair found:
# Incomplete QA pair found: (4) A Licensee who has accepted accountability has assumed responsibility for radiation activities. They can be:
# Incomplete QA pair found: a.Citizens
# Incomplete QA pair found: b.Being the corporation responsible for activities which expose people
# Incomplete QA pair found: to ionized radiation b.
# Incomplete QA pair found:
# Incomplete QA pair found: Licensee have responsibilities under Radiation
# Incomplete QA pair found: Activities for accountability which are listed as part of Canadian legal statutes. (4-26
# Incomplete QA pair found: SCTB and the
# Incomplete QA pair found: Safety Control Act.
# Incomplete QA pair found:
# Incomplete QA pair found: The Licencing agreement allows you to operate any licensed facilities according
# Incomplete QA pair found: the requirements as mentioned in regulatory Document
# Incomplete QA pair found:
# Incomplete QA pair found: For the purpose of Radiation Management license holder (licencee) has accountability as explained
# Incomplete QA pair found: above and there responsibilities are detailed inside
# Incomplete QA pair found: Radiation Control Accountabilities: Section 6 for Licencers, Section9 for Dosimeters.</br>
# Generated QA pairs for the first 3 chunks:
